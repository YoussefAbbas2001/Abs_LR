# %%
from utils.generate_dataset import generate_linear_data
from utils.plotting import plot_validation
from model import LinearRegession
from train import train

# %%
x_train, y_train = generate_linear_data(n_data=100,coeff=3,intercept=1)

# %%
model = LinearRegession(input_size=1, output_size=1)

# %%
y_train
# Out:
# tensor([[  1.],
#         [  4.],
#         [  7.],
#         [ 10.],
#         [ 13.],
#         [ 16.],
#         [ 19.],
#         [ 22.],
#         [ 25.],
#         [ 28.],
#         [ 31.],
#         [ 34.],
#         [ 37.],
#         [ 40.],
#         [ 43.],
#         [ 46.],
#         [ 49.],
#         [ 52.],
#         [ 55.],
#         [ 58.],
#         [ 61.],
#         [ 64.],
#         [ 67.],
#         [ 70.],
#         [ 73.],
#         [ 76.],
#         [ 79.],
#         [ 82.],
#         [ 85.],
#         [ 88.],
#         [ 91.],
#         [ 94.],
#         [ 97.],
#         [100.],
#         [103.],
#         [106.],
#         [109.],
#         [112.],
#         [115.],
#         [118.],
#         [121.],
#         [124.],
#         [127.],
#         [130.],
#         [133.],
#         [136.],
#         [139.],
#         [142.],
#         [145.],
#         [148.],
#         [151.],
#         [154.],
#         [157.],
#         [160.],
#         [163.],
# ...

# %%
plot_validation(x_train, y_train,  model(x_train))
